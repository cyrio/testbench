# %% [markdown]
# # Analyse exploratoire des données

# %%
import pandas as pd
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
df= pd.read_csv('/home/fitec/Mise en situation professionnelle/Projets FITEC/Test Bench/TimeSeries/TimeSeries_20121001_071145_b4f0944fd20df856edc385fe0b423471.csv', sep =';')

# %%
df.head()
# Out:
#          DATE     HEURE                             PHASE      PR_1      PR_2  \
# 0  01/10/2012  07:05:17  6dd4dbc3fcdbc5ba95c4b0955373aea2  0.507865  1.326732
# 1  01/10/2012  07:05:18  6dd4dbc3fcdbc5ba95c4b0955373aea2  0.375170  1.371984
# 2  01/10/2012  07:05:19  6dd4dbc3fcdbc5ba95c4b0955373aea2  0.495805  1.371984
# 3  01/10/2012  07:05:20  6dd4dbc3fcdbc5ba95c4b0955373aea2  0.411360  1.281477
# 4  01/10/2012  07:05:21  6dd4dbc3fcdbc5ba95c4b0955373aea2  0.435485  1.236225
#
#        PR_3       PR_4     TEMP_1     TEMP_2   BRAKE_1  SPEED_1  SENSOR_1  \
# 0 -0.912404  24.373335  77.852050  138.50830  1.743795    119.0      -9.0
# 1 -1.180488  61.298904  77.910645  138.50098  1.745571    126.0      -9.0
# 2 -1.070100  59.706768  77.991210  138.53027  1.749122    126.0      -9.0
# 3 -1.243568  76.606310  77.888670  138.29590  2.391733    126.0      -9.0
# 4 -1.275104  54.355743  77.874020  138.43506  2.441452    126.0      -9.0
#
#     SENSOR_2  SENSOR_3    SENSOR_4  SENSOR_5
# ...

# %% [markdown]
# ## Essai 1er DF

# %% [markdown]
# ### 1. Distribution des valeurs des capteurs

# %%
fig=plt.figure(figsize=(30,30))
plt.subplot(3,3,1)
df.boxplot(column='SENSOR_1')
plt.subplot(3,3,2)
df.boxplot(column='SENSOR_2')
plt.subplot(3,3,3)
df.boxplot(column='SENSOR_3')
plt.subplot(3,3,4)
df.boxplot(column='SENSOR_4')
plt.subplot(3,3,5)
df.boxplot(column='SENSOR_5')
# Out:
# <AxesSubplot:>

# %%
df.plot(y=['SENSOR_1', 'SENSOR_2','SENSOR_3','SENSOR_4','SENSOR_5'], subplots=True, layout=(4,4), figsize=(15,15))
# Out:
# array([[<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>],
#        [<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>],
#        [<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>],
#        [<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>]],
#       dtype=object)

# %% [markdown]
# ### 2. Distribution des valeurs de chargement

# %%
fig=plt.figure(figsize=(30,30))
df.plot(y=['PR_1', 'PR_2','PR_3','PR_4','TEMP_1','TEMP_2','BRAKE_1'], subplots=True, layout=(4,4), figsize=(15,15))
# Out:
# array([[<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>],
#        [<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>],
#        [<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>],
#        [<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>]],
#       dtype=object)

# %%
df['PR_1'].mean()
# Out:
# 218.01197943037988

# %% [markdown]
# ## Essai 2ème DF

# %%
df2= pd.read_csv('/home/fitec/Mise en situation professionnelle/Projets FITEC/Test Bench/TimeSeries/TimeSeries_20121022_095917_94fc7a4b82113c58c1d2cb5abe8d70f3.csv', sep =';')

# %% [markdown]
# ### 1. Distribution des valeurs des capteurs

# %%
fig=plt.figure(figsize=(30,30))
plt.subplot(3,3,1)
df2.boxplot(column='SENSOR_1')
plt.subplot(3,3,2)
df2.boxplot(column='SENSOR_2')
plt.subplot(3,3,3)
df2.boxplot(column='SENSOR_3')
plt.subplot(3,3,4)
df2.boxplot(column='SENSOR_4')
plt.subplot(3,3,5)
df2.boxplot(column='SENSOR_5')
# Out:
# <AxesSubplot:>

# %%
df2.plot(y=['SENSOR_1', 'SENSOR_2','SENSOR_3','SENSOR_4','SENSOR_5'], subplots=True, layout=(4,4), figsize=(30,30))
# Out:
# array([[<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>],
#        [<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>],
#        [<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>],
#        [<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>]],
#       dtype=object)

# %% [markdown]
# ### 2. Distribution des valeurs de chargement

# %%
fig=plt.figure(figsize=(30,30))
df2.plot(y=['PR_1', 'PR_2','PR_3','PR_4','TEMP_1','TEMP_2','BRAKE_1'], subplots=True, layout=(4,4), figsize=(30,30))
# Out:
# array([[<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>],
#        [<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>],
#        [<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>],
#        [<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>]],
#       dtype=object)

# %% [markdown]
# ## Essai 3ème DF

# %%
df3= pd.read_csv('/home/fitec/Mise en situation professionnelle/Projets FITEC/Test Bench/TimeSeries/TimeSeries_20121016_172344_0dade278d1aa5c9b3d6ef67b31d4e6ce.csv', sep =';')

# %% [markdown]
# ### 1. Distribution des valeurs des capteurs

# %%
fig=plt.figure(figsize=(30,30))
plt.subplot(3,3,1)
df3.boxplot(column='SENSOR_1')
plt.subplot(3,3,2)
df3.boxplot(column='SENSOR_2')
plt.subplot(3,3,3)
df3.boxplot(column='SENSOR_3')
plt.subplot(3,3,4)
df3.boxplot(column='SENSOR_4')
plt.subplot(3,3,5)
df3.boxplot(column='SENSOR_5')
# Out:
# <AxesSubplot:>

# %%
df3.plot(y=['SENSOR_1', 'SENSOR_2','SENSOR_3','SENSOR_4','SENSOR_5'], subplots=True, layout=(4,4), figsize=(30,30))
# Out:
# array([[<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>],
#        [<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>],
#        [<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>],
#        [<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>]],
#       dtype=object)

# %% [markdown]
# ### 2. Distribution des valeurs de chargement

# %%
fig=plt.figure(figsize=(30,30))
df3.plot(y=['PR_1', 'PR_2','PR_3','PR_4','TEMP_1','TEMP_2','BRAKE_1'], subplots=True, layout=(4,4), figsize=(30,30))
# Out:
# array([[<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>],
#        [<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>],
#        [<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>],
#        [<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>]],
#       dtype=object)

# %% [markdown]
# ## Essai 4ème DF

# %%
df4= pd.read_csv('/home/fitec/Mise en situation professionnelle/Projets FITEC/Test Bench/TimeSeries/TimeSeries_20121010_122305_023b6341f7599977d56c812e3984a296.csv', sep =';')

# %% [markdown]
# ### 1. Distribution des valeurs des capteurs

# %%
fig=plt.figure(figsize=(30,30))
plt.subplot(3,3,1)
df4.boxplot(column='SENSOR_1')
plt.subplot(3,3,2)
df4.boxplot(column='SENSOR_2')
plt.subplot(3,3,3)
df4.boxplot(column='SENSOR_3')
plt.subplot(3,3,4)
df4.boxplot(column='SENSOR_4')
plt.subplot(3,3,5)
df4.boxplot(column='SENSOR_5')
# Out:
# <AxesSubplot:>

# %%
df4.plot(y=['SENSOR_1', 'SENSOR_2','SENSOR_3','SENSOR_4','SENSOR_5'], subplots=True, layout=(4,4), figsize=(30,30))
# Out:
# array([[<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>],
#        [<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>],
#        [<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>],
#        [<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>]],
#       dtype=object)

# %% [markdown]
# ### 2. Distribution des valeurs de chargement

# %%
fig=plt.figure(figsize=(30,30))
df4.plot(y=['PR_1', 'PR_2','PR_3','PR_4','TEMP_1','TEMP_2','BRAKE_1'], subplots=True, layout=(4,4), figsize=(30,30))
# Out:
# array([[<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>],
#        [<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>],
#        [<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>],
#        [<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>]],
#       dtype=object)
